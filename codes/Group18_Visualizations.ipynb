# %% [markdown]
# # Spot Distributions

# %%
from historical_peaks import get_spot_distribution
import matplotlib.pyplot as plt

dist_2000 = get_spot_distribution(2000)
dist_2019 = get_spot_distribution(2019)

plt.subplot(1, 2, 1)
plt.pie(dist_2000, autopct='%1.0f%%', colors=['#d43928', '#22b55b', '#f2de24', '#b8b8b8'])
plt.title('Year 2000')

plt.subplot(1, 2, 2)
plt.pie(dist_2019, autopct='%1.0f%%',  colors=['#d43928', '#22b55b', '#f2de24', '#b8b8b8'])
plt.title('Year 2019')
plt.legend(['Admin (A)', 'Grad (B)', 'Student (S)', 'Visitor (V)'], loc = 'lower left', bbox_to_anchor=(-0.4, -.24, 0.5, 0.5))

plt.show()

# %% [markdown]
# # Spot Use by Type

# %%
from historical_peaks import compare_university
import numpy as np

quarter = 'Spring'
ax = compare_university(quarter)
ax.plot()
plt.yticks(np.arange(50, 101, step=10))
plt.title('University Parking Trends (2000-2019) -- '+quarter+' Quarters', fontsize=18)
plt.ylabel('Percent Full')
plt.xlabel('Year')

plt.legend(loc = 'lower right')
plt.xticks(range(2000, 2020))
plt.locator_params(axis='x', nbins=10)

# %% [markdown]
# # Best Lot to Park In

# %%
from find_parking import * 

frame_dictionary = collect_dictionary()
   
lot, values = get_best_lot_times(frame_dictionary, 'S', 'Mon')

plt.bar(['8am', '10am', '12pm', '2pm'], values)
plt.title('Open Student Parking for Lot '+lot)
plt.xlabel('Time of Day')
plt.ylabel('Number of Open Spaces')
# Out:
# Text(0, 0.5, 'Number of Open Spaces')

# %% [markdown]
# # Total empty spaces heatmap

# %%
# %matplotlib inline
from emptyspaces_heatmap import get_figure
get_figure()
# Out:
# Fixed formatting
# C:\Users\iaman\Desktop\Projects\Project 2019.9\ECE143\Project\ECE143_FinalProject\codes\emptyspaces_heatmap.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_useful.loc[len(df_useful) + 1] = data

# %% [markdown]
# # Average Occupancy Level of Different Neighbors

# %%
from locations_heatmap import get_GoogleMap, get_the_dataframe
get_GoogleMap(get_the_dataframe('2000/01'))
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
get_GoogleMap(get_the_dataframe('2014/15'))
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Distribution of Empty Spaces (By Permit)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['S spot', 'A spot', 'B spot', 'V spot']
sizes = [2740.3, 579.45, 895.975, 232.525]
colors = ['#FFFF64', '#DC143C','#3CB371',
          '#DCDCDC']
explode = (0.05, 0.01, 0.01, 0.01) 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, explode=explode)
centre_circle = plt.Circle((0,0),0.30,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.set(aspect="equal", title='What is the distribution of empty spaces in year 2000 (by permit)?')

plt.tight_layout()
plt.show()

# %%
labels = ['S spot', 'A spot', 'B spot', 'V spot']
sizes = [79.4375, 179.5625, 148.23684210526315, 78.04347826086956]
colors = ['#FFFF64', '#DC143C', '#3CB371',
          '#DCDCDC']
explode = (0.05, 0.01, 0.01, 0.01) 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, explode=explode)

centre_circle = plt.Circle((0,0),0.30,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.set(aspect="equal", title='What is the distribution of empty spaces in year 2019 (by permit)?') 

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average empty spaces based on time of the day (By permit)

# %%
Times = ('8am', '9am', '10am', '11am', '12pm', '1pm', '2pm', '3pm', '4pm', '5pm')
y_pos = np.arange(len(Times))
performance = [3371.516666666667,2847.983333333333,2279.266666666667,1889.75,1758.0666666666666,1717.4166666666667,1711.85,1910.8833333333334,2215.3,2603.5333333333333]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, Times)
plt.ylabel('Empty Spots')
plt.title('Average empty spaces based on time of the day (S Permit)')

plt.show()

# %%
Times = ('8am', '9am', '10am', '11am', '12pm', '1pm', '2pm', '3pm', '4pm', '5pm')
y_pos = np.arange(len(Times))
performance = [1297.5833333333333,911.8666666666667,553.3333333333334,365.73333333333335,323.43333333333334,329.15,328.8666666666667,383.3,509.26666666666665,630.5]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, Times)
plt.ylabel('Empty Spots')
plt.title('Average empty spaces based on time of the day (A Permit)')

plt.show()

# %%
Times = ('8am', '9am', '10am', '11am', '12pm', '1pm', '2pm', '3pm', '4pm', '5pm')
y_pos = np.arange(len(Times))
performance = [2473.233333333333,1497.7,934.3333333333334,934.3333333333334,698.95,687.3333333333334,729.3,896.95,1339.3833333333334,2130.65]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, Times)
plt.ylabel('Empty Spots')
plt.title('Average empty spaces based on time of the day (B Permit)')

plt.show()

# %%
Times = ('8am', '9am', '10am', '11am', '12pm', '1pm', '2pm', '3pm', '4pm', '5pm')
y_pos = np.arange(len(Times))
performance = [598.0333333333333,419.15,259.1166666666667,181.95,182.93333333333334,205.0,196.36666666666667,234.65,289.6666666666667,350.21666666666664]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, Times)
plt.ylabel('Empty Spots')
plt.title('Average empty spaces based on time of the day (Visitor Parking Spaces)')

plt.show()
